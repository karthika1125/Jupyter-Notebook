# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9,12,20])
plt.plot(ypoint,"o:b")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([4,2,6,8])
y=np.array([10,15,20,25])
plt.plot(x,linestyle = 'dashed',c='hotpink')
plt.plot(y,linestyle='dotted',c='purple')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,200])
y=np.array([0,300])
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([8,10,12,14,16,18,20])
y=np.array([100,150,200,250,300,350,400])
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([4,10,8,16,7,3,18,22])
y=np.array([100,110,220,200,450,300,315,400])
plt.plot(x,y,linestyle="dashed",c='yellow',marker='*',linewidth='5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,9,10,2,13,18,20,25,1])
y=np.array([120,100,205,110,220,300,405,603,700])
plt.plot(x,linestyle='dashed',c='hotpink',marker='o',linewidth='3',ms='5')
plt.plot(y,linestyle='dashed',c='pink',marker='*',linewidth='3',ms='5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([4,10,8,16,7,3,18,22])
y=np.array([100,110,220,200,450,300,315,400])
plt.plot(x,linestyle="dashed",c='yellow',marker='*',linewidth='5')
plt.plot(y,linestyle="dashed",c='black',marker='*',linewidth='5')

plt.show()

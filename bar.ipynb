# %%
 import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,22])
y=np.array([99,66,87,88,56])
plt.scatter(x,y)
plt.show()

# %%
 import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,22])
y=np.array([99,66,87,88,56])
plt.scatter(x,y)

x=np.array([2,2,8,1,5])
y=np.array([100,105,84,105,90])
plt.scatter(x,y)
plt.show()

# %%
 import matplotlib.pyplot as plt
import numpy as np
x=np.array([5,7,8,7,22])
y=np.array([99,66,87,88,56])
colors=np.array([0,10,20,30,40])
plt.scatter(x,y, c=colors,cmap='viridis')
plt.colorbar()
plt.show()

# %%
 import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D','E'])
y=np.array([99,66,87,88,56])
plt.bar(x,y,color='red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y=np.array([35,25,25,15])
mylabels=['Apple','Banana','cherry','Dates']
myexplode=[0.2,0,0.2,0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y=np.array([35,25,25,15])
mylabels=['Apple','Banana','cherry','Dates']
myexplode=[0,0,0.2,0]
plt.pie(y,labels=mylabels,explode=myexplode)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y=np.array([35,25,25,15])
mylabels=['Apple','Banana','cherry','Dates']
myexplode=[0.2,0,0.2,0]
plt.pie(y,labels=mylabels,explode=myexplode,shadow=True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y=np.array([35,25,25,15])
mylabels=['Apple','Banana','cherry','Dates']
myexplode=[0.2,0,0.2,0]
mycolors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(y,labels=mylabels,explode=myexplode,shadow=True,colors=mycolors)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y=np.array([35,25,25,15])
mylabels=['Apple','Banana','cherry','Dates']
myexplode=[0,0,0.2,0]
mycolors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(y,labels=mylabels,explode=myexplode,shadow=True,colors=mycolors)
plt.legend(title='Fruits')
plt.show()

# %%
 import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D','E'])
y=np.array([99,66,87,88,56])
plt.barh(x,y,color='blue')
plt.show()

# %%
 import matplotlib.pyplot as plt
import numpy as np
x=np.array(['A','B','C','D','E'])
y=np.array([99,66,87,88,56])
plt.bar(x,y,color='green',width=0.2)
plt.show()

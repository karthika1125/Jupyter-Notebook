# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,90,95,100,105,110,120,125,130])
y=np.array([240,250,260,270,280,290,300,310,320,330])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'green','size':15}
plt.title("sports watch Data",fontdict=font1)
plt.xlabel("Average pulse",fontdict=font2)
plt.ylabel("Calorie",fontdict=font2)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([10,20,30,40])
y=np.array([100,200,300,400])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'green','size':15}
plt.title("sports watch Data",fontdict=font1)
plt.xlabel("Average pulse",fontdict=font2)
plt.ylabel("Calorie",fontdict=font2)
plt.grid()
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([10,20,30,40])
y=np.array([100,200,300,400])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'green','size':15}
plt.title("sports watch Data",fontdict=font1)
plt.xlabel("Average pulse",fontdict=font2)
plt.ylabel("Calorie",fontdict=font2)
plt.grid(axis="y")
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([10,20,30,40])
y=np.array([100,200,300,400])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'green','size':15}
plt.title("sports watch Data",fontdict=font1)
plt.xlabel("Average pulse",fontdict=font2)
plt.ylabel("Calorie",fontdict=font2)
plt.grid(axis='x')
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([10,20,30,40])
y=np.array([100,200,300,400])
font1={'family':'serif','color':'blue','size':20}
font2={'family':'serif','color':'green','size':15}
plt.title("sports watch Data",fontdict=font1)
plt.xlabel("Average pulse",fontdict=font2)
plt.ylabel("Calorie",fontdict=font2)
plt.grid(color='red',linestyle="dashed")
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot:1
x=np.array([0,1,2,3,4])
y=np.array([3,8,1,10,15])
plt.subplot(1,2,1)
plt.plot(x,y)


#plot:2
x=np.array([0,1,2,3,4])
y=np.array([10,20,30,40,50])
plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot:1
x=np.array([0,1,2,3,4])
y=np.array([3,8,1,10,15])
plt.subplot(2,1,1)
plt.plot(x,y)


#plot:2
x=np.array([0,1,2,3,4])
y=np.array([10,20,30,40,50])
plt.subplot(2,1,2)
plt.plot(x,y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot:1
x=np.array([0,1,2,3,4])
y=np.array([3,8,1,10,15])
plt.subplot(3,2,1)
plt.plot(x,y)



#plot:2
x=np.array([0,1,2,3,4])
y=np.array([10,20,30,40,50])
plt.subplot(3,2,2)
plt.plot(x,y)

#plot:3
x=np.array([0,11,21,13,41])
y=np.array([105,200,305,400,505])
plt.subplot(3,2,3)
plt.plot(x,y)

#plot:4
x=np.array([10,1,25,37,40])
y=np.array([10,20,30,40,50])
plt.subplot(3,2,4)
plt.plot(x,y)

#plot:5
x=np.array([0,15,24,30,45])
y=np.array([10,20,30,40,50])
plt.subplot(3,2,5)
plt.plot(x,y)

#plot:6
x=np.array([50,18,26,34,49])
y=np.array([100,200,300,400,500])
plt.subplot(3,2,6)
plt.plot(x,y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot:1
x=np.array([0,1,2,3,4])
y=np.array([3,8,1,10,15])
plt.subplot(2,3,1)
plt.plot(x,y)


#plot:2
x=np.array([0,1,2,3,4])
y=np.array([10,20,30,40,50])
plt.subplot(2,3,2)
plt.plot(x,y)

#plot:3
x=np.array([0,11,21,13,41])
y=np.array([105,200,305,400,505])
plt.subplot(2,3,3)
plt.plot(x,y)

#plot:4
x=np.array([10,1,25,37,40])
y=np.array([10,20,30,40,50])
plt.subplot(2,3,4)
plt.plot(x,y)

#plot:5
x=np.array([0,15,24,30,45])
y=np.array([10,20,30,40,50])
plt.subplot(2,3,5)
plt.plot(x,y)

#plot:6
x=np.array([50,18,26,34,49])
y=np.array([100,200,300,400,500])
plt.subplot(2,3,6)
plt.plot(x,y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot:1
x=np.array([0,1,2,3,4])
y=np.array([3,8,1,10,15])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.grid(color='red',linestyle='dashed')


#plot:2
x=np.array([0,1,2,3,4])
y=np.array([10,20,30,40,50])
plt.subplot(2,3,2)
plt.plot(x,y)
plt.grid(color='lavender',linestyle='dashed')

#plot:3
x=np.array([0,11,21,13,41])
y=np.array([105,200,305,400,505])
plt.subplot(2,3,3)
plt.plot(x,y)
plt.grid(color='hotpink',linestyle='dashed')

#plot:4
x=np.array([10,1,25,37,40])
y=np.array([10,20,30,40,50])
plt.subplot(2,3,4)
plt.plot(x,y)
plt.grid(color='purple',linestyle='dashed')

#plot:5
x=np.array([0,15,24,30,45])
y=np.array([10,20,30,40,50])
plt.subplot(2,3,5)
plt.plot(x,y)
plt.grid(color='green',linestyle='dashed')

#plot:6
x=np.array([50,18,26,34,49])
y=np.array([100,200,300,400,500])
plt.subplot(2,3,6)
plt.plot(x,y)
plt.grid(color='yellow',linestyle='dashed')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot:1
x=np.array([0,1,2,3,4])
y=np.array([3,8,1,10,15])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.title('sales')


#plot:2
x=np.array([0,1,2,3,4])
y=np.array([10,20,30,40,50])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.title('profit')
plt.suptitle('customer')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
#plot:1
x=np.array([0,1,2,3,4])
y=np.array([3,8,1,10,15])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.grid(color='red',linestyle='dashed')
plt.title('sales:Mon')


#plot:2
x=np.array([0,1,2,3,4])
y=np.array([10,20,30,40,50])
plt.subplot(2,3,2)
plt.plot(x,y)
plt.grid(color='lavender',linestyle='dashed')
plt.title('sales:tue')

#plot:3
x=np.array([0,11,21,13,41])
y=np.array([105,200,305,400,505])
plt.subplot(2,3,3)
plt.plot(x,y)
plt.grid(color='hotpink',linestyle='dashed')
plt.title('sales:wed')

#plot:4
x=np.array([10,1,25,37,40])
y=np.array([10,20,30,40,50])
plt.subplot(2,3,4)
plt.plot(x,y)
plt.grid(color='purple',linestyle='dashed')
plt.title('sales:thu')

#plot:5
x=np.array([0,15,24,30,45])
y=np.array([10,20,30,40,50])
plt.subplot(2,3,5)
plt.plot(x,y)
plt.grid(color='green',linestyle='dashed')
plt.title('sales:fri')

#plot:6
x=np.array([50,18,26,34,49])
y=np.array([100,200,300,400,500])
plt.subplot(2,3,6)
plt.plot(x,y)
plt.grid(color='yellow',linestyle='dashed')
plt.title('sales:sat')
plt.suptitle('customer')
plt.show()

# %%
import pandas as pd
df=pd.read_csv('Movies Dataset.csv')
df
# Out:
#             id                                title  \
# 0       385687                               Fast X
# 1       758323                  The Pope's Exorcist
# 2       640146    Ant-Man and the Wasp: Quantumania
# 3       677179                            Creed III
# 4       502356          The Super Mario Bros. Movie
# ...        ...                                  ...
# 722791  900760  A Incessante Conquista da Escuridão
# 722792  957818                  Hollywood Varieties
# 722793  648905                 A Man Must Be Strong
# 722794  576855                        Stastriptease
# 722795  968161                        Gising Sining
#
#                                            genres original_language  \
# 0                           Action-Crime-Thriller                en
# 1                         Horror-Mystery-Thriller                en
# 2                Action-Adventure-Science Fiction                en
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722796 entries, 0 to 722795
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    722796 non-null  int64
#  1   title                 722790 non-null  object
#  2   genres                511934 non-null  object
#  3   original_language     722796 non-null  object
#  4   overview              604198 non-null  object
#  5   popularity            722796 non-null  float64
#  6   production_companies  337170 non-null  object
#  7   release_date          670329 non-null  object
#  8   budget                722796 non-null  float64
#  9   revenue               722796 non-null  float64
#  10  runtime               688346 non-null  float64
#  11  status                722796 non-null  object
#  12  tagline               108098 non-null  object
#  13  vote_average          722796 non-null  float64
# ...

# %%
df.head()
# Out:
#        id                              title  \
# 0  385687                             Fast X
# 1  758323                The Pope's Exorcist
# 2  640146  Ant-Man and the Wasp: Quantumania
# 3  677179                          Creed III
# 4  502356        The Super Mario Bros. Movie
#
#                                       genres original_language  \
# 0                      Action-Crime-Thriller                en
# 1                    Horror-Mystery-Thriller                en
# 2           Action-Adventure-Science Fiction                en
# 3                               Drama-Action                en
# 4  Animation-Family-Adventure-Fantasy-Comedy                en
#
#                                             overview  popularity  \
# 0  Over many missions and against impossible odds...    6682.100
# 1  Father Gabriele Amorth Chief Exorcist of the V...    5953.227
# 2  Super-Hero partners Scott Lang and Hope van Dy...    4425.387
# ...

# %%
df.head(10)
# Out:
#        id                                title  \
# 0  385687                               Fast X
# 1  758323                  The Pope's Exorcist
# 2  640146    Ant-Man and the Wasp: Quantumania
# 3  677179                            Creed III
# 4  502356          The Super Mario Bros. Movie
# 5  631842                   Knock at the Cabin
# 6  603692                 John Wick: Chapter 4
# 7  840326                                 Sisu
# 8  646389                                Plane
# 9  569094  Spider-Man: Across the Spider-Verse
#
#                                        genres original_language  \
# 0                       Action-Crime-Thriller                en
# 1                     Horror-Mystery-Thriller                en
# 2            Action-Adventure-Science Fiction                en
# 3                                Drama-Action                en
# 4   Animation-Family-Adventure-Fantasy-Comedy                en
# ...

# %%
df.tail()
# Out:
#             id                                title  genres original_language  \
# 722791  900760  A Incessante Conquista da Escuridão     NaN                pt
# 722792  957818                  Hollywood Varieties  Comedy                en
# 722793  648905                 A Man Must Be Strong     NaN                it
# 722794  576855                        Stastriptease     NaN                de
# 722795  968161                        Gising Sining     NaN                tl
#
#                                                  overview  popularity  \
# 722791  Two voices talk about the impermanence of the ...         0.6
# 722792  Entertainment trade-paper headlines report the...         0.6
# 722793  Jack starts the transition in order to let his...         0.6
# 722794                                                NaN         0.6
# 722795  In a country where fascism foolishness of peop...         0.6
#
# ...

# %%
df.describe()
# Out:
#                   id     popularity        budget       revenue       runtime  \
# count  722796.000000  722796.000000  7.227960e+05  7.227960e+05  6.883460e+05
# mean   526917.587990       1.807185  3.924801e+05  9.776385e+05  1.989186e+02
# std    253164.471522      18.839397  8.136181e+06  2.010908e+07  8.581987e+04
# min         2.000000       0.600000  0.000000e+00 -1.200000e+01  0.000000e+00
# 25%    328947.750000       0.600000  0.000000e+00  0.000000e+00  5.000000e+00
# 50%    533364.500000       0.600000  0.000000e+00  0.000000e+00  5.000000e+01
# 75%    737817.250000       1.290000  0.000000e+00  0.000000e+00  9.000000e+01
# max    968161.000000    6682.100000  5.000000e+09  2.920357e+09  5.050505e+07
#
#         vote_average     vote_count
# count  722796.000000  722796.000000
# mean        2.443118      27.610661
# std         3.175498     381.523676
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# ...

# %%
df.shape
# Out:
# (722796, 20)

# %%
df.dtypes
# Out:
# id                        int64
# title                    object
# genres                   object
# original_language        object
# overview                 object
# popularity              float64
# production_companies     object
# release_date             object
# budget                  float64
# revenue                 float64
# runtime                 float64
# status                   object
# tagline                  object
# vote_average            float64
# vote_count              float64
# credits                  object
# keywords                 object
# poster_path              object
# backdrop_path            object
# recommendations          object
# dtype: object

# %%
print(df['title'])
# Out:
# 0                                      Fast X
# 1                         The Pope's Exorcist
# 2           Ant-Man and the Wasp: Quantumania
# 3                                   Creed III
# 4                 The Super Mario Bros. Movie
#                          ...
# 722791    A Incessante Conquista da Escuridão
# 722792                    Hollywood Varieties
# 722793                   A Man Must Be Strong
# 722794                          Stastriptease
# 722795                          Gising Sining
# Name: title, Length: 722796, dtype: object

# %%
df[["title","original_language"]]
# Out:
#                                       title original_language
# 0                                    Fast X                en
# 1                       The Pope's Exorcist                en
# 2         Ant-Man and the Wasp: Quantumania                en
# 3                                 Creed III                en
# 4               The Super Mario Bros. Movie                en
# ...                                     ...               ...
# 722791  A Incessante Conquista da Escuridão                pt
# 722792                  Hollywood Varieties                en
# 722793                 A Man Must Be Strong                it
# 722794                        Stastriptease                de
# 722795                        Gising Sining                tl
#
# [722796 rows x 2 columns]

# %%
df.iloc[5]
# Out:
# id                                                                 631842
# title                                                  Knock at the Cabin
# genres                                            Horror-Mystery-Thriller
# original_language                                                      en
# overview                While vacationing at a remote cabin a young gi...
# popularity                                                       3422.537
# production_companies    Blinding Edge Pictures-Universal Pictures-Film...
# release_date                                                   2023-02-01
# budget                                                         20000000.0
# revenue                                                        52000000.0
# runtime                                                             100.0
# status                                                           Released
# tagline                 Save your family or save humanity. Make the ch...
# ...

# %%
df.loc[9,'genres']
# Out:
# 'Action-Adventure-Animation-Science Fiction'

# %%
df[df["genres"]=='Drama-Action']
# Out:
#             id                                  title        genres  \
# 3       677179                              Creed III  Drama-Action
# 76      943822  Prizefighter: The Life of Jem Belcher  Drama-Action
# 391      59440                                Warrior  Drama-Action
# 1057    391757          Never Back Down: No Surrender  Drama-Action
# 2427    619329                         Munthiri Kaadu  Drama-Action
# ...        ...                                    ...           ...
# 712112  507165                                 Kiraak  Drama-Action
# 713886  524865                                 Salute  Drama-Action
# 714797  551211                          Mission China  Drama-Action
# 716751  653889                                 Garang  Drama-Action
# 720012  481222                  The Armless Swordsman  Drama-Action
#
#        original_language                                           overview  \
# ...

# %%
df_sort = df.sort_values(by="original_language", ascending=False)
df_sort
# Out:
#             id                                              title  \
# 439355  938771                                     Friday's Ghost
# 249487  467795                                       Fishy Stones
# 699018  486843                                     Thunder Valley
# 448369  939509                                               Lola
# 677182  486850                                         Bona manzi
# ...        ...                                                ...
# 667335  634499           One Day in the Life of a Men's Monastery
# 415438  882752                             I’ve Been Here All Day
# 320597  927448                           Christmas the Wright Way
# 228762  462710                                        Un altro me
# 576330  197074  Lee Ritenour & Dave Grusin: Montreux Jazz Fest...
#
#               genres original_language  \
# 439355        Comedy                zu
# 249487  Comedy-Crime                zu
# 699018           NaN                zu
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# title                        6
# genres                  210862
# original_language            0
# overview                118598
# popularity                   0
# production_companies    385626
# release_date             52467
# budget                       0
# revenue                      0
# runtime                  34450
# status                       0
# tagline                 614698
# vote_average                 0
# vote_count                   0
# credits                 225107
# keywords                512525
# poster_path             185230
# backdrop_path           500272
# recommendations         688076
# dtype: int64

# %%
df.drop('backdrop_path', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'title', 'genres', 'original_language', 'overview', 'popularity',
#        'production_companies', 'release_date', 'budget', 'revenue', 'runtime',
#        'status', 'tagline', 'vote_average', 'vote_count', 'poster_path',
#        'recommendations'],
#       dtype='object')

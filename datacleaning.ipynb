# %%
import pandas as pd
df=pd.read_csv('Copy of AccidentReports.csv',encoding='latin')
df
# Out:
#        DISTRICTNAME            UNITNAME      Crime_No  Year  RI  \
# 0          Bagalkot          Amengad PS  1.047010e+16  2016   1
# 1          Bagalkot          Amengad PS  1.047010e+16  2016   1
# 2          Bagalkot          Amengad PS  1.047010e+16  2016   1
# 3          Bagalkot          Amengad PS  1.047010e+16  2016   1
# 4          Bagalkot          Amengad PS  1.047010e+16  2016   1
# ...             ...                 ...           ...   ...  ..
# 301756       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023   1
# 301757       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023   1
# 301758       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023   1
# 301759       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023   1
# 301760       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023   1
#
#         Noofvehicle_involved Accident_Classification   Accident_Spot  \
# 0                          1          Road Accidents      Bottleneck
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301761 entries, 0 to 301760
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   DISTRICTNAME              301761 non-null  object
#  1   UNITNAME                  301761 non-null  object
#  2   Crime_No                  301761 non-null  float64
#  3   Year                      301761 non-null  int64
#  4   RI                        301761 non-null  int64
#  5   Noofvehicle_involved      301761 non-null  int64
#  6   Accident_Classification   301759 non-null  object
#  7   Accident_Spot             301760 non-null  object
#  8   Accident_Location         301758 non-null  object
#  9   Accident_SubLocation      301760 non-null  object
#  10  Accident_SpotB            176684 non-null  object
#  11  Main_Cause                301759 non-null  object
#  12  Hit_Run                   301758 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# DISTRICTNAME                     0
# UNITNAME                         0
# Crime_No                         0
# Year                             0
# RI                               0
# Noofvehicle_involved             0
# Accident_Classification          2
# Accident_Spot                    1
# Accident_Location                3
# Accident_SubLocation             1
# Accident_SpotB              125077
# Main_Cause                       2
# Hit_Run                          3
# Severity                         2
# Collision_Type                   1
# Junction_Control                 1
# Road_Character                   4
# Road_Type                        2
# Surface_Type                     2
# Surface_Condition                1
# Road_Condition                   3
# Weather                          1
# Lane_Type                   239253
# Road_Markings               271601
# Spot_Conditions             248412
# Side_Walk                   254704
# RoadJunction                301761
# ...

# %%
column_to_drop=["RI", "RoadJunction","Road_Markings","Spot_Conditions","Side_Walk","Lane_Type","Accident_Classification","Collision_TypeB","Distance_LandMark_First","Accident_Description","Accident_SpotB" ,"landmark_second","Distance_LandMark_First","Distance_LandMark_Second","Landmark_first","Accident_Road"]

# %%
df_cleaned=df.drop(columns=column_to_drop)
df_cleaned
# Out:
#        DISTRICTNAME            UNITNAME      Crime_No  Year  \
# 0          Bagalkot          Amengad PS  1.047010e+16  2016
# 1          Bagalkot          Amengad PS  1.047010e+16  2016
# 2          Bagalkot          Amengad PS  1.047010e+16  2016
# 3          Bagalkot          Amengad PS  1.047010e+16  2016
# 4          Bagalkot          Amengad PS  1.047010e+16  2016
# ...             ...                 ...           ...   ...
# 301756       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023
# 301757       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023
# 301758       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023
# 301759       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023
# 301760       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023
#
#         Noofvehicle_involved   Accident_Spot    Accident_Location  \
# 0                          1      Bottleneck          Rural Areas
# 1                          1          Bridge  Villages settlement
# ...

# %%
df_cleaned.isnull().sum()
# Out:
# DISTRICTNAME            0
# UNITNAME                0
# Crime_No                0
# Year                    0
# Noofvehicle_involved    0
# Accident_Spot           1
# Accident_Location       3
# Accident_SubLocation    1
# Main_Cause              2
# Hit_Run                 3
# Severity                2
# Collision_Type          1
# Junction_Control        1
# Road_Character          4
# Road_Type               2
# Surface_Type            2
# Surface_Condition       1
# Road_Condition          3
# Weather                 1
# Latitude                0
# Longitude               0
# dtype: int64

# %%
numerical_columnss=df_cleaned.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['DISTRICTNAME', 'UNITNAME', 'Accident_Spot', 'Accident_Location',
#        'Accident_SubLocation', 'Main_Cause', 'Hit_Run', 'Severity',
#        'Collision_Type', 'Junction_Control', 'Road_Character', 'Road_Type',
#        'Surface_Type', 'Surface_Condition', 'Road_Condition', 'Weather'],
#       dtype='object')

# %%
numerical_columns=df_cleaned.select_dtypes(include=['number']).columns
numerical_columns
# Out:
# Index(['Crime_No', 'Year', 'Noofvehicle_involved', 'Latitude', 'Longitude'], dtype='object')

# %%
df_cleaned[categorical_columns]=df_cleaned[categorical_columns].fillna('unknown')

# %%
df_cleaned[numerical_columns]=df_cleaned[numerical_columns].fillna(df_cleaned[numerical_columns].median())

# %%
df_cleaned.isnull().sum()
# Out:
# DISTRICTNAME            0
# UNITNAME                0
# Crime_No                0
# Year                    0
# Noofvehicle_involved    0
# Accident_Spot           0
# Accident_Location       0
# Accident_SubLocation    0
# Main_Cause              0
# Hit_Run                 0
# Severity                0
# Collision_Type          0
# Junction_Control        0
# Road_Character          0
# Road_Type               0
# Surface_Type            0
# Surface_Condition       0
# Road_Condition          0
# Weather                 0
# Latitude                0
# Longitude               0
# dtype: int64

# %%
df_cleaned.drop_duplicates()
# Out:
#        DISTRICTNAME            UNITNAME      Crime_No  Year  \
# 0          Bagalkot          Amengad PS  1.047010e+16  2016
# 1          Bagalkot          Amengad PS  1.047010e+16  2016
# 2          Bagalkot          Amengad PS  1.047010e+16  2016
# 3          Bagalkot          Amengad PS  1.047010e+16  2016
# 4          Bagalkot          Amengad PS  1.047010e+16  2016
# ...             ...                 ...           ...   ...
# 301756       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023
# 301757       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023
# 301758       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023
# 301759       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023
# 301760       Yadgir  Yadgiri Traffic PS  1.097820e+16  2023
#
#         Noofvehicle_involved   Accident_Spot    Accident_Location  \
# 0                          1      Bottleneck          Rural Areas
# 1                          1          Bridge  Villages settlement
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder={}
for column in categorical_columns:
    le=LabelEncoder()
    df_cleaned[column]=le.fit_transform(df_cleaned[column])
    labelencoder[column]=le
df_cleaned
# Out:
#         DISTRICTNAME  UNITNAME      Crime_No  Year  Noofvehicle_involved  \
# 0                  0        19  1.047010e+16  2016                     1
# 1                  0        19  1.047010e+16  2016                     1
# 2                  0        19  1.047010e+16  2016                     2
# 3                  0        19  1.047010e+16  2016                     2
# 4                  0        19  1.047010e+16  2016                     1
# ...              ...       ...           ...   ...                   ...
# 301756            37       713  1.097820e+16  2023                     2
# 301757            37       713  1.097820e+16  2023                     2
# 301758            37       713  1.097820e+16  2023                     1
# 301759            37       713  1.097820e+16  2023                     1
# 301760            37       713  1.097820e+16  2023                     1
#
#         Accident_Spot  Accident_Location  Accident_SubLocation  Main_Cause  \
# ...

# %%
from sklearn.preprocessing import StandardScaler
scalar={}
for column in numerical_columns:
    sc=StandardScaler()
    df_cleaned[column]=sc.fit_transform(df_cleaned[[column]])
    scalar[column]=sc
df_cleaned
# Out:
#         DISTRICTNAME  UNITNAME  Crime_No      Year  Noofvehicle_involved  \
# 0                  0        19 -0.330259 -1.485937             -0.940881
# 1                  0        19 -0.330259 -1.485937             -0.940881
# 2                  0        19 -0.330259 -1.485937              0.684637
# 3                  0        19 -0.330259 -1.485937              0.684637
# 4                  0        19 -0.330259 -1.485937             -0.940881
# ...              ...       ...       ...       ...                   ...
# 301756            37       713  2.366388  1.524587              0.684637
# 301757            37       713  2.366388  1.524587              0.684637
# 301758            37       713  2.366388  1.524587             -0.940881
# 301759            37       713  2.366388  1.524587             -0.940881
# 301760            37       713  2.366388  1.524587             -0.940881
#
#         Accident_Spot  Accident_Location  Accident_SubLocation  Main_Cause  \
# ...

# %%
from  sklearn.preprocessing import MinMaxScaler
scalar={}

for column in numerical_columns:
    sc=MinMaxScaler()
    df_cleaned[column]=sc.fit_transform(df_cleaned[[column]])
    scalar[column]=sc
df_cleaned
# Out:
#         DISTRICTNAME  UNITNAME  Crime_No  Year  Noofvehicle_involved  \
# 0                  0        19  0.058555   0.0              0.000000
# 1                  0        19  0.058555   0.0              0.000000
# 2                  0        19  0.058555   0.0              0.013514
# 3                  0        19  0.058555   0.0              0.013514
# 4                  0        19  0.058555   0.0              0.000000
# ...              ...       ...       ...   ...                   ...
# 301756            37       713  0.985407   1.0              0.013514
# 301757            37       713  0.985407   1.0              0.013514
# 301758            37       713  0.985407   1.0              0.000000
# 301759            37       713  0.985407   1.0              0.000000
# 301760            37       713  0.985407   1.0              0.000000
#
#         Accident_Spot  Accident_Location  Accident_SubLocation  Main_Cause  \
# ...
